# %%
import numpy as np
import pandas as pd
import swc.aeon.io as io
import swc.aeon.io.reader as reader
from swc.aeon.schema.streams import Device
import os
from dotmap import DotMap
import matplotlib.pyplot as plt

# %%
base_dir = "../../temp_data/sub-OneShotAruco/ses-001_date-2026-07-22T13-11-29/"

markers = pd.read_csv(os.path.join(base_dir, 'markers/markers.csv'))
subject_camera = pd.read_csv(os.path.join(base_dir, 'subject/subject.csv'))

time_diff = markers["Seconds"].values - subject_camera["Seconds"].values

plt.figure()
plt.boxplot(time_diff)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x210e5e9d850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x210e5e9ea90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x210e5e9ce90>],
#  'medians': [<matplotlib.lines.Line2D at 0x210e5e9fa90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x210e5eac210>],
#  'means': []}
